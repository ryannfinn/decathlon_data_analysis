# %% [markdown]
# Objectives:
# 1. The team in charge of this influence campaign wants to know if the objective of rejuvenating its target population has been achieved.
# 2. In addition, Fitness Cardio wonders if this campaign was profitable for Decathlon. To answer this last question, you can apply an average margin rate of 20%*.
#
# The main objective of this influencer campaign was to recruit new Generation Z customers from social networks.

# %% [markdown]
# ### Preparation

# %%
# importing relevant packages
import pandas as pd
from glob import glob
import datetime
import numpy as np

# %%
# CONSTANTS

# Campaign date
CAMPAIGN_DATE = datetime.date(2020,9,4)
# Model code for the products being promoted
LS_PRODUCT_MODEL_CODES = [5015822, 7635140, 7166996, 2486222]
# The budget for the marketing campaign
MARKETING_BUDGET = 30000

# %%
# getting the path for CSVs that contain the data 
glob("dataset/*")
# Out:
# ['dataset/d_sku.csv',
#  'dataset/d_business_unit.csv',
#  'dataset/flow_audience.csv',
#  'dataset/f_transaction_detail.csv',
#  'dataset/d_customers.csv']

# %% [markdown]
# ### Loading the CSVs into dataframes

# %%
# dataframe; each row: information of each product item
df_products = pd.read_csv("dataset/d_sku.csv")
# dataframe; each row: information of each customer
df_customers = pd.read_csv("dataset/d_customers.csv")
# dataframe; each row: information about each transaction
df_transactions = pd.read_csv("dataset/f_transaction_detail.csv")
# dataframe; each row: one audience flow on the Decathlon website
df_flow = pd.read_csv("dataset/flow_audience.csv")
# dataframe; each row: each online/offline store
df_unit = pd.read_csv("dataset/d_business_unit.csv")

# %% [markdown]
# ### Profitability

# %%
# First select the products relevant to the campaign from the product dataframe
df_rel_products = df_products[df_products["mdl_num_model_r3"].isin(LS_PRODUCT_MODEL_CODES)].sort_values(by=["mdl_num_model_r3"])
df_rel_products
# Discovered that each model has plenty of items; each have a different item number
# Out:
#       sku_idr_sku  mdl_num_model_r3  mdl_blue_product  fam_num_family  \
# 5421      7455088         2486222.0                 0           10790
# 5419      7442821         2486222.0                 0           10790
# 5759      7451543         2486222.0                 0           10790
# 3033      7449064         2486222.0                 0           10790
# 2325      7460340         2486222.0                 0           10790
# 2381      7448470         2486222.0                 0           10790
# 5711      7457353         2486222.0                 0           10790
# 3032      7467777         5015822.0                 0           10788
# 3897      7463476         5015822.0                 0           10788
# 2388      7463948         5015822.0                 0           10788
# 203       7452821         5015822.0                 0           10788
# 2581      7458509         5015822.0                 0           10788
# 1862      7455608         7166996.0                 0           34344
# 3577      7458813         7166996.0                 0           34344
# 6868      7467008         7166996.0                 0           34344
# 6468      7452661         7166996.0                 0           34344
# 6745      7468857         7166996.0                 0           34344
# 6652      7457374         7166996.0                 0           34344
# 118       7446648         7635140.0                 0           34344
# 5160      7450422         7635140.0                 0           34344
# 4399      7449633         7635140.0                 0           34344
# 2762      7458761         7635140.0                 0           34344
# 1012      7448829         7635140.0                 0           34344
# 5420      7461697         7635140.0                 0           34344
# 6869      7452235         7635140.0                 0           34344
#
#          family_label  sdp_num_sub_department       sdp_label  \
# 5421    FITNESS SHOES                    2798  FITNESS CARDIO
# 5419    FITNESS SHOES                    2798  FITNESS CARDIO
# 2232701  2020-09-04 10:28:49                  NaN      7467777
# 2232842  2020-09-04 11:20:01  2020-09-04 11:20:05      7458813
# 2232848  2020-09-04 10:56:14  2020-09-04 10:56:20      7449064
#
#          but_idr_business_unit  ctm_customer_id ctm_zip_code the_to_type  \
# 58810                   262186     3.924791e+14           34      online
# 58811                   262186     3.924791e+14           34      online
# 66139                   262186     8.604535e+14           75      online
# 66140                   262186     6.897239e+14           60      online
# 66141                   262186     6.897239e+14           60      online
# ...                        ...              ...          ...         ...
# 2232699                 262186     6.638106e+14           63      online
# 2232700                 262186     9.462075e+14           74      online
# 2232701                 262186     9.462075e+14           74      online
# 2232842                 262186     7.363493e+14           78      online
# 2232848                 262186     8.754140e+14           28      online
#
#         the_transaction_status tdt_type_detail  f_to_tax_in  f_qty_item
# 58810                 finished            sale         20.0           1
# 58811                 finished            sale         20.0           1
# 66139                 finished            sale         20.0           1
# 66140                 finished            sale         45.0           1
# 66141                 finished            sale         20.0           1
# ...                        ...             ...          ...         ...
# 2232699               canceled            sale         20.0           1
# 2232700               canceled          return        -20.0          -1
# 2232701               canceled            sale         20.0           1
# 2232842               canceled          return        -35.0          -1
# 2232848               finished          return        -45.0           0
#
# [10196 rows x 13 columns]

# %%
# We hypothetically set a period of effectiveness for the campaign of 14 days.
period_enddate = CAMPAIGN_DATE + datetime.timedelta(days = 14)
period_enddate
# Out:
# datetime.date(2020, 9, 18)

# %%
# However, the data provided only extends to 13th of September.
# Therefore we can't make whole 2 weeks the into consideration.
df_transcations_4items["the_date_transaction"].max()
# Out:
# Timestamp('2020-09-13 17:19:43')

# %%
# Here, we used the_date_transaction as the date of the query, 
# since it is the most relevant metrics showing the time of the purchase behaviour where the customers intention took place.

# change the datatype of "the_date_transaction" column to datetime format for calculation
df_transcations_4items["the_date_transaction"] = pd.to_datetime(df_transcations_4items["the_date_transaction"])
df_transcations_4items["the_date_transaction"]
# Out:
# /var/folders/l2/pb0v6kq90dl82mv427v4y7c80000gp/T/ipykernel_74024/482725317.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_transcations_4items["the_date_transaction"] = pd.to_datetime(df_transcations_4items["the_date_transaction"])
# 58810     2020-09-01 12:13:27
# 58811     2020-09-01 12:13:27
# 66139     2020-09-04 10:48:18
# 66140     2020-09-04 10:47:14
# 66141     2020-09-04 10:47:14
#                   ...
# 2232699   2020-09-04 10:25:50
# 2232700   2020-09-04 10:28:49
# 2232701   2020-09-04 10:28:49
# 2232842   2020-09-04 11:20:01
# 2232848   2020-09-04 10:56:14
# Name: the_date_transaction, Length: 10196, dtype: datetime64[ns]

# %%
# the transcations of the 4 products in the designated period
df_transcations_4items_inperiod = (df_transcations_4items[
    (df_transcations_4items["the_date_transaction"].dt.date <= period_enddate) & 
    (df_transcations_4items["the_date_transaction"].dt.date >= CAMPAIGN_DATE)]
    .sort_values(by=["the_date_transaction"]))

df_transcations_4items_inperiod
# Out:
#                            the_transaction_id tdt_date_to_returned  \
# 1639134  50-13-13-20200904003505-1-1826401674  2020-09-04 09:27:06
# 1639133  50-13-13-20200904003505-1-1826401674  2020-09-04 09:27:06
# 1639132  50-13-13-20200904003505-1-1826401674  2020-09-04 09:27:06
#
# 1266780         7-28-28-20200912193522-2-8372  2020-09-12 19:35:22
# 2213417       7-225-225-20200913134905-3-1060  2020-09-13 13:49:05
# 377609        7-779-779-20200913143948-5-3652  2020-09-13 14:39:48
#
#         the_date_transaction  the_date_authorized  sku_idr_sku  \
# 1639134  2020-09-04 00:35:05  2020-09-04 08:49:37      7458509
# 1639133  2020-09-04 00:35:05  2020-09-04 08:49:37      7457374
# 1639132  2020-09-04 00:35:05  2020-09-04 08:49:37      7448829
# 782046   2020-09-04 00:35:40                  NaN      7458813
# 781986   2020-09-04 00:35:40                  NaN      7449633
# ...                      ...                  ...          ...
# 1202740  2020-09-12 19:04:58  2020-09-12 19:04:58      7461697
# 1266781  2020-09-12 19:35:22  2020-09-12 19:35:22      7463948
# 1266780  2020-09-12 19:35:22  2020-09-12 19:35:22      7460340
# 2213417  2020-09-13 13:49:05  2020-09-13 13:49:05      7449633
# 377609   2020-09-13 14:39:48  2020-09-13 14:39:48      7449633
#
#          but_idr_business_unit  ctm_customer_id ctm_zip_code the_to_type  \
# 1639134                 262186     1.191847e+14           83      online
# 1639133                 262186     1.191847e+14           83      online
# 1639132                 262186     1.191847e+14           83      online
# 782046                  262186     7.714755e+13           61      online
# 781986                  262186     7.714755e+13           61      online
# ...                        ...              ...          ...         ...
# 1202740                  33601     2.333176e+14          NaN     offline
# 1266781                  33610     6.346633e+14          NaN     offline
# 1266780                  33610     6.346633e+14          NaN     offline
# 2213417                  33791     2.029395e+14          NaN     offline
# 377609                   34330              NaN            *     offline
#
#         the_transaction_status tdt_type_detail  f_to_tax_in  f_qty_item
# 1639134               canceled          return        -20.0          -1
# 1639133               canceled          return        -35.0          -1
# 1639132               canceled          return        -20.0          -1
# 782046                canceled          return        -35.0          -1
# 781986                canceled          return        -20.0          -1
# ...                        ...             ...          ...         ...
# 1202740               finished          return        -20.0          -1
# 1266781               finished          return        -20.0          -1
# 1266780               finished          return        -45.0          -1
# 2213417               finished          return        -20.0          -1
# 377609                finished          return        -20.0          -1
#
# [1293 rows x 13 columns]

# %%
# all sales of the 4 products in the designated period (return not considered)
df_sales_4items_inperiod = (df_transcations_4items_inperiod
                            [df_transcations_4items_inperiod["tdt_type_detail"] == "sale"])
# the transaction id for the return transaction in the period
return_id = df_return_4items_inperiod["the_transaction_id"]

# the valid sales dataframe after dropping the returned products rows
df_valid_sales_4items_inperiod = df_sales_4items_inperiod[~df_sales_4items_inperiod["the_transaction_id"].isin(return_id)]
df_valid_sales_4items_inperiod
# Out:
#                            the_transaction_id tdt_date_to_returned  \
# 1036755  50-13-13-20200904082649-1-1827560023                  NaN
# 1036756  50-13-13-20200904082649-1-1827560023                  NaN
# 1076127  50-13-13-20200904083416-1-1827524213                  NaN
# 1076130  50-13-13-20200904083416-1-1827524213                  NaN
# 1076129  50-13-13-20200904083416-1-1827524213                  NaN
# ...                                       ...                  ...
# 1478096       7-116-116-20200912192602-4-7808                  NaN
# 391151       7-189-189-20200913104410-21-4075                  NaN
# 1160892      7-189-189-20200913143554-10-3501                  NaN
# 446650            7-9-9-20200913163813-6-1540                  NaN
# 524762        7-779-779-20200913171943-1-4335                  NaN
#
#         the_date_transaction  the_date_authorized  sku_idr_sku  \
# 1036755  2020-09-04 08:26:49  2020-09-04 08:28:33      7449633
# 1036756  2020-09-04 08:26:49  2020-09-04 08:28:33      7460340
# 1076127  2020-09-04 08:34:16  2020-09-04 08:34:41      7458509
# 1076130  2020-09-04 08:34:16  2020-09-04 08:34:41      7463476
# 1076129  2020-09-04 08:34:16  2020-09-04 08:34:41      7458813
# ...                      ...                  ...          ...
# 1478096  2020-09-12 19:26:02  2020-09-12 19:26:02      7463476
# 391151   2020-09-13 10:44:10  2020-09-13 10:44:10      7446648
# 1160892  2020-09-13 14:35:54  2020-09-13 14:35:54      7467777
# 446650   2020-09-13 16:38:13  2020-09-13 16:38:13      7460340
# 524762   2020-09-13 17:19:43  2020-09-13 17:19:43      7449633
#
#          but_idr_business_unit  ctm_customer_id ctm_zip_code the_to_type  \
# 1036755                 262186     5.768569e+14           73      online
# 1036756                 262186     5.768569e+14           73      online
# 1076127                 262186     5.545599e+14           91      online
# 1076130                 262186     5.545599e+14           91      online
# 1076129                 262186     5.545599e+14           91      online
# ...                        ...              ...          ...         ...
# 1478096                  33691     2.161764e+14          NaN     offline
# 391151                   33758     7.568892e+14          NaN     offline
# 1160892                  33758     4.186005e+14          NaN     offline
# 446650                   33592              NaN           13     offline
# 524762                   34330     3.388947e+14          NaN     offline
#
#         the_transaction_status tdt_type_detail  f_to_tax_in  f_qty_item
# 1036755               finished            sale         20.0           1
# 1036756               finished            sale         45.0           1
# 1076127               finished            sale         20.0           1
# 1076130               finished            sale         20.0           1
# 1076129               finished            sale         35.0           1
# ...                        ...             ...          ...         ...
# 1478096               finished            sale         20.0           1
# 391151                finished            sale         20.0           1
# 1160892               finished            sale         20.0           1
# 446650                finished            sale         45.0           1
# 524762                finished            sale         20.0           1
#
# [7638 rows x 13 columns]

# %% [markdown]
# Now we calculate the direct revenue from the campaign in the designated period from this dataframe.

# %%
# The total turnover for the 4 items in the campaign in the designated period
total_turnover = df_valid_sales_4items_inperiod["f_to_tax_in"].sum()
total_turnover
# Out:
# 227843.0

# %% [markdown]
# Since the average margin rate is 20%, we would have the following calculation:

# %%
# This is assuming that the 20% margin rate has accounted for all the other costs apart from the IG marketing campaign
# The total cost for the product sold 
total_product_cost = total_turnover/1.2
total_product_cost
# Out:
# 189869.1666666667

# %%
profit = total_turnover - total_product_cost - MARKETING_BUDGET
profit
# Out:
# 7973.833333333314

# %% [markdown]
# After deducting the marketing budget, there is still a 7,973 Euro profit. Therefore, the campaign was profitable for Decathlon.

# %% [markdown]
# ---------------

# %% [markdown]
# ### Effectiveness of the Influence Campaign

# %% [markdown]
# However, to answer the question of whether the campaign was successful in rejuvenating its target population, more data should be looked at.
# The target population is new Generation Z customers. More specifically, they should be attracted from the social network channel. To answer such question, I think we should compare the number of Cardio Fitness products purchased before and after the campaign, with specific regards to the women in generation Z.

# %%
# Query for the Fitness Cardio Women Products
# Since products for men usually contain "M " in the beginning of the "family_label" tag, we exclude them for our analysis
df_fitnesscardio_women = df_products[(df_products["unv_label"] == "FITNESS CARDIO") & ~(df_products["family_label"].str.startswith("M "))]
df_fitnesscardio_women
# Out:
#       sku_idr_sku  mdl_num_model_r3  mdl_blue_product  fam_num_family  \
# 1         7362028         7424823.0                 0           34344
# 2         7332974         9316616.0                 0           10790
# 3         7418117          907001.0                 0           34344
# 7         7264755         6219651.0                 0           10788
# 9         7306220         1974237.0                 0           10788
# ...           ...               ...               ...             ...
# 7259      7475525         9941122.0                 0             270
# 7267      6988089         3374362.0                 0            3087
# 7268      2050523         9184597.0                 0           10789
# 7271      7319354         3649811.0                 0           34344
# 7272      1915016         1565016.0                 0             350
#
#          family_label  sdp_num_sub_department       sdp_label  \
# 1     FIT CONF W CLOT                    1587  FITNESS CARDIO
# 2       FITNESS SHOES                    2798  FITNESS CARDIO
# 3     FIT CONF W CLOT                    1587  FITNESS CARDIO
# 7           FIT W BRA                    1587  FITNESS CARDIO
# 9           FIT W BRA                    1587  FITNESS CARDIO
# ...               ...                     ...             ...
# 7259  FIT JUMPIN ROPE                    1666  FITNESS CARDIO
# 7267  FIT BAGS,ACCESS                    2198  FITNESS CARDIO
# 7268         W ENERGY                    1587  FITNESS CARDIO
# 7271  FIT CONF W CLOT                    1587  FITNESS CARDIO
# 7272   SPECIAL ORDERS                    1666  FITNESS CARDIO
#
#       dpt_num_department dpt_label  unv_num_univers       unv_label  \
# 1                     88   FITNESS                6  FITNESS CARDIO
# 2                     88   FITNESS                6  FITNESS CARDIO
# 3                     88   FITNESS                6  FITNESS CARDIO
# 7                     88   FITNESS                6  FITNESS CARDIO
# 9                     88   FITNESS                6  FITNESS CARDIO
# ...                  ...       ...              ...             ...
# 7259                  88   FITNESS                6  FITNESS CARDIO
# 7267                  88   FITNESS                6  FITNESS CARDIO
# 7268                  88   FITNESS                6  FITNESS CARDIO
# 7271                  88   FITNESS                6  FITNESS CARDIO
# 7272                  88   FITNESS                6  FITNESS CARDIO
#
#       pnt_num_product_nature product_nature_label category_label  \
# 1                      25055               SHORTS       CLOTHING
# 2                      25126                SHOES       FOOTWEAR
# 3                      10988          LEGGING 7/8       CLOTHING
# 7                      25076           SPORTS BRA       CLOTHING
# 9                      25082                  BRA       CLOTHING
# ...                      ...                  ...            ...
# 7259                       0            UNDEFINED            NaN
# 7267                   26531           SPORTS BAG      ACCESSORY
# 7268                   25032               JACKET       CLOTHING
# 7271                   25014              T-SHIRT       CLOTHING
# 7272                       0            UNDEFINED            NaN
#
#      brd_type_brand_libelle         sku_date_end
# 1                        MP  2999-12-31 23:59:59
# 2                        MP  2999-12-31 23:59:59
# 3                        MP  2999-12-31 23:59:59
# 7                        MP  2999-12-31 23:59:59
# 9                        MP  2999-12-31 23:59:59
# ...                     ...                  ...
# 7259                    AMI  2999-12-31 23:59:59
# 7267                     MP  2999-12-31 23:59:59
# 7268                     MP  2999-12-31 23:59:59
# 7271                     MP  2999-12-31 23:59:59
# 7272                    AMI  2999-12-31 23:59:59
#
# [2157 rows x 16 columns]

# %%
# filter only the transactions for Fitness Cardio Women Products
df_female_fitnesscardio_transactions = df_transactions[df_transactions["sku_idr_sku"].isin(df_fitnesscardio_women.sku_idr_sku)]

# Joining the transaction dataframe with the customer information
df_transactions_withcusinfo = pd.merge(df_female_fitnesscardio_transactions, df_customers, left_on = "ctm_customer_id", right_on = "loyalty_card_num", how = "inner")

# Select only the purchase from Generation Z members
# We don't deduct male members here, since we are already targeting female products.
df_genz_transactions = df_transactions_withcusinfo[df_transactions_withcusinfo.year_birthdate >= 1995]
df_genz_transactions
# Out:
#                           the_transaction_id tdt_date_to_returned  \
# 307           7-292-292-20200829154610-7-481                  NaN
# 308           7-292-292-20200829154610-7-481                  NaN
# 381     50-13-13-20200825103804-1-1758594495                  NaN
# 564          7-179-179-20200827155609-2-8881                  NaN
# 565          7-179-179-20200827155609-2-8881                  NaN
# ...                                      ...                  ...
# 312036  50-13-13-20200904112026-1-1828066076                  NaN
# 312037  50-13-13-20200904112026-1-1828066076                  NaN
# 312236         7-62-62-20200909111930-9-8670  2020-09-09 11:19:30
# 312237         7-62-62-20200909111930-9-8670                  NaN
# 312433  50-13-13-20200913164652-1-1866312858                  NaN
#
#        the_date_transaction  the_date_authorized  sku_idr_sku  \
# 307     2020-08-29 15:46:10  2020-08-29 15:46:10      7260976
# 308     2020-08-29 15:46:10  2020-08-29 15:46:10      7264064
# 381     2020-08-25 10:38:04  2020-08-25 10:38:08      7422363
# 564     2020-08-27 15:56:09  2020-08-27 15:56:09      7360829
# 565     2020-08-27 15:56:09  2020-08-27 15:56:09      7396655
# ...                     ...                  ...          ...
# 312036  2020-09-04 11:20:26  2020-09-04 11:21:02      7457374
# 312037  2020-09-04 11:20:26  2020-09-04 11:21:02      7463948
# 312236  2020-09-09 11:19:30  2020-09-09 11:19:30      7198860
# 312237  2020-09-09 11:19:30  2020-09-09 11:19:30      7333058
# 312433  2020-09-13 16:46:52  2020-09-13 16:46:57      7277146
#
#         but_idr_business_unit  ctm_customer_id ctm_zip_code the_to_type  \
# 307                     33854     2.149419e+14          NaN     offline
# 308                     33854     2.149419e+14          NaN     offline
# 381                    262186     5.393912e+14           59      online
# 564                     33748     5.343895e+14          NaN     offline
# 565                     33748     5.343895e+14          NaN     offline
# ...                       ...              ...          ...         ...
# 312036                 262186     9.953709e+14           85      online
# 312037                 262186     9.953709e+14           85      online
# 312236                  33640     3.738735e+14          NaN     offline
# 312237                  33640     3.738735e+14          NaN     offline
# 312433                 262186     4.962765e+14           77      online
#
#        the_transaction_status  ... email_is_valid  mobile_is_valid  \
# 307                  finished  ...          False             True
# 308                  finished  ...          False             True
# 381                  finished  ...           True             True
# 564                  finished  ...           True             True
# 565                  finished  ...           True             True
# ...                       ...  ...            ...              ...
# 312036               finished  ...           True             True
# 312037               finished  ...           True             True
# 312236               finished  ...           True             True
# 312237               finished  ...           True             True
# 312433                shipped  ...           True             True
#
#         loyalty_card_creation_date  but_idr_business_unit_usual  \
# 307            2007-08-29 04:24:00                        33633
# 308            2007-08-29 04:24:00                        33633
# 381            2020-05-10 12:47:11                        33693
# 564            2019-10-17 14:08:06                        33748
# 565            2019-10-17 14:08:06                        33748
# ...                            ...                          ...
# 312036         2019-03-16 14:39:22                        33912
# 312037         2019-03-16 14:39:22                        33912
# 312236         2015-06-08 09:21:10                        33894
# 312237         2015-06-08 09:21:10                        33894
# 312433         2019-04-20 09:34:19                        33706
#
#         but_idr_business_unit_creator  cnt_country_code_creator optin_sport  \
# 307                             33592                        FR           1
# 308                             33592                        FR           1
# 381                             33693                        FR           1
# 564                             33748                        FR           0
# 565                             33748                        FR           0
# ...                               ...                       ...         ...
# 312036                          34441                        FR           0
# 312037                          34441                        FR           0
# 312236                          33894                        FR           1
# 312237                          33894                        FR           1
# 312433                          33706                        FR           0
#
#        optin_review optin_event last_purchase_date
# 307               1           1         2021-03-03
# 308               1           1         2021-03-03
# 381               1           0         2021-03-05
# 564               0           0         2021-03-04
# 565               0           0         2021-03-04
# ...             ...         ...                ...
# 312036            0           0         2021-02-19
# 312037            0           0         2021-02-19
# 312236            1           1         2021-02-14
# 312237            1           1         2021-02-14
# 312433            0           0         2021-02-15
#
# [6573 rows x 27 columns]

# %%
# resample the transaction date and compare the number of sales of Fitness Cardio Women Products before and after the campaign
df_genz_transactions["the_date_transaction"] = pd.to_datetime(df_genz_transactions["the_date_transaction"])

# Since matching the returned items would be too complicated, for simplicity, we would only use the turnover here to 
# get an average number of money made from the products sold, in which the sales figure is balanced out by the return figure
df_genz_transactions_inperiod = (df_genz_transactions[
    (df_genz_transactions["the_date_transaction"].dt.date <= period_enddate) & 
    (df_genz_transactions["the_date_transaction"].dt.date >= CAMPAIGN_DATE)])
df_genz_transactions_outperiod = (df_genz_transactions[
    (df_genz_transactions["the_date_transaction"].dt.date < CAMPAIGN_DATE)])
# Out:
# /var/folders/l2/pb0v6kq90dl82mv427v4y7c80000gp/T/ipykernel_74024/529949098.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_genz_transactions["the_date_transaction"] = pd.to_datetime(df_genz_transactions["the_date_transaction"])
# 87410.75

# %%
# the total transactions turnout in the period 
amt_inperiod = df_genz_transactions_inperiod.f_to_tax_in.sum()
days = df_genz_transactions_inperiod["the_date_transaction"].dt.date.unique().shape[0]
# the average transactions turnout in the period
amt_inperiod/days
# Out:
# 8741.075

# %%
# the total transactions turnout not in the period 
amt_outperiod = df_genz_transactions_outperiod.f_to_tax_in.sum()
days = df_genz_transactions_outperiod["the_date_transaction"].dt.date.unique().shape[0]
# the average transactions turnout not in the period 
amt_outperiod/days
# Out:
# 6170.565454545454

# %% [markdown]
# As we can see that the average transactions amount for the Fitness Cardio Women Productsin the campaign period is much higher (41%) than that before the campaign period. Telling from this metrics, we can conclude that the rejuvenation is successful.

# %% [markdown]
# Let's also take a look of the traffic in the designated period for the Fitness Cardio Women Products:

# %%
# filter only the traffic for the 4 products
df_flow_fitnesscardio_women = df_flow[df_flow["product_id_model"].isin(df_fitnesscardio_women.mdl_num_model_r3)]
df_flow_fitnesscardio_women
# Out:
#         hit_date  url_referer_host  product_id_model product_instock  \
# 5     2020-09-08  www.decathlon.fr         1757502.0     unavailable
# 6     2020-09-02  www.decathlon.fr         9841743.0       partially
# 8     2020-09-07  www.decathlon.fr          566583.0       available
# 9     2020-08-27  www.decathlon.fr         3002369.0       available
# 11    2020-09-05  www.decathlon.fr         5776605.0       available
# ...          ...               ...               ...             ...
# 51519 2020-09-11  www.decathlon.fr         6579446.0     unavailable
# 51520 2020-09-04  www.decathlon.fr         2707647.0       available
# 51522 2020-09-03  www.decathlon.fr         9647368.0       available
# 51527 2020-09-03  www.decathlon.fr         5739523.0     unavailable
# 51528 2020-08-28  www.decathlon.fr          566583.0       available
#
#       device_type  avg_note  nb_reviews  tot_visitors
# 5          mobile      3.67         3.0            32
# 6          tablet      4.38         8.0             1
# 8         desktop      4.54        41.0             1
# 9         desktop      0.00         0.0             2
# 11         tablet      4.67         3.0             1
# ...           ...       ...         ...           ...
# 51519      tablet      4.45       276.0             6
# 51520      mobile      4.29       340.0             8
# 51522      mobile      4.37       433.0            24
# 51527     desktop      4.40       401.0            35
# 51528     desktop      4.49        39.0             4
#
# [19545 rows x 8 columns]

# %%
# filter traffic before and after the designated period
df_flow_fitnesscardio_women["hit_date"] = pd.to_datetime(df_flow_fitnesscardio_women["hit_date"])
df_flow_fitnesscardio_women_inperiod = (df_flow_fitnesscardio_women[
    (df_flow_fitnesscardio_women["hit_date"].dt.date <= period_enddate) & 
    (df_flow_fitnesscardio_women["hit_date"] .dt.date >= CAMPAIGN_DATE)])
df_flow_fitnesscardio_women_outperiod = (df_flow_fitnesscardio_women[
    (df_flow_fitnesscardio_women["hit_date"] .dt.date < CAMPAIGN_DATE)])
# Out:
# /var/folders/l2/pb0v6kq90dl82mv427v4y7c80000gp/T/ipykernel_74024/3495696846.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_flow_fitnesscardio_women["hit_date"] = pd.to_datetime(df_flow_fitnesscardio_women["hit_date"])

# %%
# The average number of visitors each day before the campaign
nvbc = df_flow_fitnesscardio_women_inperiod.tot_visitors.sum()
# The number of days in the data period before the campaign
days = df_flow_fitnesscardio_women_inperiod["hit_date"].dt.date.unique().shape[0]
# The average number of visitors each day before the campaign 
nvbc/days
# Out:
# 20657.5

# %%
# 
nvac = df_flow_fitnesscardio_women_outperiod.tot_visitors.sum()
# 
days = df_flow_fitnesscardio_women_outperiod["hit_date"].dt.date.unique().shape[0]
# 
nvac/days
# Out:
# 14526.5

# %% [markdown]
# The

# %%
# from flow audience; just checking lau leung
# maybe get some indicators from digital marketing
# conversion and things
# utm, specifically because of the link
# join member because of that

# %%
# other insight : offline or online?

# %%
# check similar category; may not be exactly those products being purchased
# think from a consumer perspective

# %%
# count how long as the campaign effect period
# need explain: allow how long customers buying them? may need find literature; say decathlon usual is?
# additional information: any other factors that may affect that like other campaigns or social factors

# %%
# Limitation:
only members; if only outside then may not accurate
flow audience if have tracker then utm, may know traffic
